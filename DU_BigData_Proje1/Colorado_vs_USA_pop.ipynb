# %%
import pandas as pd

# %%
path="nst-est2017-alldata.csv"
pop_df=pd.read_csv(path)

# %%
pop_df.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0    10.0      0        0    0.0     United States    308745538.0
# 1    20.0      1        0    0.0  Northeast Region     55317240.0
# 2    20.0      2        0    0.0    Midwest Region     66927001.0
# 3    20.0      3        0    0.0      South Region    114555744.0
# 4    20.0      4        0    0.0       West Region     71945553.0
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0        308758105.0      309338421.0      311644280.0      313993272.0
# 1         55318350.0       55388349.0       55642659.0       55860261.0
# 2         66929794.0       66973360.0       67141501.0       67318295.0
# 3        114563024.0      114869241.0      116060993.0      117291728.0
# 4         71946937.0       72107471.0       72799127.0       73522988.0
#
#       ...       RDOMESTICMIG2015  RDOMESTICMIG2016  RDOMESTICMIG2017  \
# ...

# %%
a=pop_df.columns
type(a)
a[0:20]
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'NAME', 'CENSUS2010POP',
#        'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011',
#        'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
#        'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017', 'NPOPCHG_2010',
#        'NPOPCHG_2011', 'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014'],
#       dtype='object')

# %%
df1= pop_df[['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'NAME', 'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017']]

# %%
df1.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0    10.0      0        0    0.0     United States    308745538.0
# 1    20.0      1        0    0.0  Northeast Region     55317240.0
# 2    20.0      2        0    0.0    Midwest Region     66927001.0
# 3    20.0      3        0    0.0      South Region    114555744.0
# 4    20.0      4        0    0.0       West Region     71945553.0
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0        308758105.0      309338421.0      311644280.0      313993272.0
# 1         55318350.0       55388349.0       55642659.0       55860261.0
# 2         66929794.0       66973360.0       67141501.0       67318295.0
# 3        114563024.0      114869241.0      116060993.0      117291728.0
# 4         71946937.0       72107471.0       72799127.0       73522988.0
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# ...

# %%
df1['NAME']
# col_df=df1.loc[(df1["NAME"]=="Colorado")&(df1["NAME"]=="United States"),:]
df1.loc[df1['NAME'].isin(['Colorado', 'United States'])]
# Out:
#     SUMLEV REGION DIVISION  STATE           NAME  CENSUS2010POP  \
# 0     10.0      0        0    0.0  United States    308745538.0
# 10    40.0      4        8    8.0       Colorado      5029196.0
#
#     ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0         308758105.0      309338421.0      311644280.0      313993272.0
# 10          5029325.0        5048029.0        5116411.0        5186330.0
#
#     POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0       316234505.0      318622525.0      321039839.0      323405935.0
# 10        5262556.0        5342311.0        5440445.0        5530105.0
#
#     POPESTIMATE2017
# 0       325719178.0
# 10        5607154.0
